# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshisingh03/All-LCA-program/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict = {"name":"XYZ","class":7,"subject":"maths","age":13,"marks":67}
print(my_dict.keys())
print(my_dict.values())

# %%
list1 = ["name","panel","rollno"]
list2 = ["ABC","B,"34]
my_dict =dict(zip(list1,list2))

print("converted dicitionary:")
print(my_dict)

# %%
my_dict = {'name':'ABC','panel': 'B','rollno':34,'marks':[65,85,67,94]}
print(sorted(my_dict))
# Out:
# ['marks', 'name', 'panel', 'rollno']

# %%
my_dict = {"name":"ABC","panel":"B","rollno":34}
keys_list = list(my_dict.keys())
values_list = list(my_dict.values())

print("list of keys:",keys_list)
print("list of values:",values_list)
# Out:
#   File "/tmp/ipykernel_1055/769788375.py", line 1
#     my_dict = {"name":"ABC":"panel":"B","rollno":34}
#                            ^
# SyntaxError: invalid syntax

# %%
my_dict = {'marks1':23,'marks2':123,'marks3':43,'marks4':13,'marks5':39}
total = sum(my_dict.values())
mean = total / len(my_dict)

print("mean of all values:",mean)
# Out:
# mean of all values: 48.2

# %%
my_dict = {"name":["yash","neel","dev"],"rollno":[11,12,13],"marks":[78,5,98]}
print("name:",my_dict["name"][2])
print("rollno:",my_dict["rollno"][1])
print("greatest marks:",max(my_dict["marks"]))
# Out:
# name: dev
# rollno: 12
# greatest marks: 98

# %%
string = input("Enter a string:")
frequency = {}
for letter in string:
     frequency[letter] += 1
else:
     frequency[letter] == 1
print("frequency of letter:",frequency)

# %%
from os import removexattr
num = int(input("enter numerator:"))
den = int(input("enter denominator:"))

quotient = num//den
remainder = num % den
result = (quotient,remainder)
print("quotient and remainder:",result)
# Out:
# enter numerator:17
# enter denominator:5
# quotient and remainder: (3, 2)
