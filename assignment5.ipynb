# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshisingh03/All-LCA-program/blob/main/assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = input("enter the string")

if s.isalnum():
    print("valid sting")
else:
    print("invalid string")
# Out:
# enter the stringmanshi122
# valid sting
