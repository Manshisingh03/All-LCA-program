# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshisingh03/All-LCA-program/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict = {"name":"manshi","age":18,"college":"mitwpu","cartoon":"shinchan"}
print(dict.keys())
print(dict.items())
print(dict.values())
print(dict.get("name"))
dict.update({"city":"patna"})
print(dict)
# Out:
# dict_keys(['name', 'age', 'college', 'cartoon'])
# dict_items([('name', 'manshi'), ('age', 18), ('college', 'mitwpu'), ('cartoon', 'shinchan')])
# dict_values(['manshi', 18, 'mitwpu', 'shinchan'])
# manshi
# {'name': 'manshi', 'age': 18, 'college': 'mitwpu', 'cartoon': 'shinchan', 'city': 'patna'}

# %%
tuple = ("kiwi","mango","banana","orange","watermelon")
print(tuple.count("oranges"))
print(tuple.index("watermelon"))
print(len(tuple))
print(max(tuple))
print(min(tuple)
)
# Out:
# 0
# 4
# 5
# watermelon
# banana
