# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshisingh03/All-LCA-program/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict = {"name":"pikachu","college":"MITWPU","state":"patna","age":15}
print(dict.keys())
print(dict.items())
print(dict.values())
print(dict.get("name"))
dict.update({"candy":"melody"})
print(dict)
# Out:
# dict_keys(['name', 'college', 'state', 'age'])
# dict_items([('name', 'pikachu'), ('college', 'MITWPU'), ('state', 'patna'), ('age', 15)])
# dict_values(['pikachu', 'MITWPU', 'patna', 15])
# pikachu
# {'name': 'pikachu', 'college': 'MITWPU', 'state': 'patna', 'age': 15, 'candy': 'melody'}

# %%
tuple = ("kiwi","mango","orange","watermelon")
print(tuple.count("watermelon"))
print(tuple.index("mango"))
print(tuple(len(tuple)))
# Out:
# 1
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2320/2325665681.py in <cell line: 0>()
#       2 print(tuple.count("watermelon"))
#       3 print(tuple.index("mango"))
# ----> 4 print(tuple(len(tuple)))
#
# TypeError: 'tuple' object is not callable
