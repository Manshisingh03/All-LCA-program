# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshisingh03/All-LCA-program/blob/main/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_right_angle_triangle(a,b,c):
  if a*a + b*b == c*c or b*b + c*c == a*a or c*c + a*a == b*b:
       return True
  else:
       return False
a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))
if is_right_angle_triangle(a,b,c):
   print("the given sides form a right angle triangle")
else:
   print("the given sides not form a right angle triangle")
# Out:
# Enter first side: 4
# Enter second side: 3
# Enter third side: 5
# the given sides form a right angle triangle
