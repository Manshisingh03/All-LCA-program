# %% [markdown]
# <a href="https://colab.research.google.com/github/Manshisingh03/All-LCA-program/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >=c:
   print("largest nuber is a")
elif b >= c and b >= a:
   print("largest number is b")
else:
   print("largest number is c")
# Out:
# Enter first number: 55
# Enter second number: 76
# Enter third number: 90
# largest number is c
